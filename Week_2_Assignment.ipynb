# %% [markdown]
# Week 2 Assignment

# %% [markdown]
# ### Certified and Licensed Healthcare Facilities within California

# %% [markdown]
# For this assignment I am using the data set that I found of all the medical facilities within California. Using code I import the data into this notebook so that I can successfully use it. Second I visualize the data I am going to use so I can get an idea of what I am working with, I also get basic characteristics of it, such as type. Then I plot some of the data so I can create a visual representation of it. Finally, I trimmed the data so that I could filter out some of the columns that were not needed for this assignment.

# %%
import geopandas as gdp

# %% [markdown]
# Purpose: I want to call the geopandas project so that I can use it later on to plot.
#
# Outcome: The project has been added into this notebook and is ready for later use.

# %%
clinic = gdp.read_file('healthcare.csv')

# %% [markdown]
# Purpose : Import the data i will be using for this assignment.
#
# Outcome: The data I uploaded to Python is ready to be used.

# %%
type (clinic)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# Purpose: See the type of data i am working with.
#
# Outcome: I know that my data is a dataframe.

# %%
clinic.head()
# Out:
#        LICENSED_CERTIFIED FLAG         T18_19      FACID FAC_STATUS_TYPE_CODE  \
# 0  LICENSED AND CERTIFIED       T18 OR T18/19  010000001                 OPEN
# 1  LICENSED AND CERTIFIED       T18 OR T18/19  010000003                 OPEN
# 2  LICENSED AND CERTIFIED       T18 OR T18/19  010000004                 OPEN
# 3  LICENSED AND CERTIFIED       T18 OR T18/19  010000005                 OPEN
# 4  LICENSED AND CERTIFIED       T18 OR T18/19  010000024                 OPEN
#
#    ASPEN_FACID     CCN TERMINAT_SW PARTICIPATION_DATE APPROVAL_DATE  ...  \
# 0  CA010000001  555120                       7-Nov-80     14-Jan-20  ...
# 1  CA010000003  056090                       1-Feb-74     13-Nov-19  ...
# 2  CA010000004  056296                      14-Sep-71     26-Dec-19  ...
# 3  CA010000005  555703                      18-Apr-97     13-Aug-19  ...
# 4  CA010000024  056300                      10-Jul-73      6-May-19  ...
#
# ...

# %% [markdown]
# Purpose: See what the data looks like, this function shows me the first five elements of the data source.
#
# Outcome: I can see the first five rows of the dataset I am using.

# %%
clinic.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 12328 entries, 0 to 12327
# Data columns (total 61 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   LICENSED_CERTIFIED              12328 non-null  object
#  1   FLAG                            12328 non-null  object
#  2   T18_19                          12328 non-null  object
#  3   FACID                           12328 non-null  object
#  4   FAC_STATUS_TYPE_CODE            12328 non-null  object
#  5   ASPEN_FACID                     12328 non-null  object
#  6   CCN                             12328 non-null  object
#  7   TERMINAT_SW                     12328 non-null  object
#  8   PARTICIPATION_DATE              12328 non-null  object
#  9   APPROVAL_DATE                   12328 non-null  object
#  10  NPI                             12328 non-null  object
#  11  CAN_BE_DEEMED_FAC_TYPE          12328 non-null  object
# ...

# %% [markdown]
# Purpose: gives me information about the columns, what type of data is in each and how many have no input
#
# Outcome: I can see exactly what type of elements each column has so then I can strategize how to use the data

# %%
clinic.shape
# Out:
# (12328, 61)

# %% [markdown]
# Purpose: tell me how many rows and columns are included within my data set
#
# Outcome: Two numbers are the output, the first us the number of rows, the second is the number of columns.

# %%
c_count= clinic['LICENSED_CERTIFIED'].value_counts()
c_count
# Out:
# LICENSED AND CERTIFIED                 7919
# LICENSED ONLY                          2908
# CERTIFIED ONLY                         1131
# NOT LICENSED/NOT CERTIFIED              363
# EXEMPT FROM LICENSURE/NOT CERTIFIED       7
# Name: LICENSED_CERTIFIED, dtype: int64

# %% [markdown]
# Purpose: count the number of clinics that pertain to each category and assign that count to a variable
#
# Outcome: I can see exactly how many elements of the data set belong to each category and I added them to a variable for later use.

# %%
c_count= c_count.reset_index()
c_count
# Out:
#                                  index  LICENSED_CERTIFIED
# 0               LICENSED AND CERTIFIED                7919
# 1                        LICENSED ONLY                2908
# 2                       CERTIFIED ONLY                1131
# 3           NOT LICENSED/NOT CERTIFIED                 363
# 4  EXEMPT FROM LICENSURE/NOT CERTIFIED                   7

# %% [markdown]
# Purpose: turn the data i had stored in the c_count variable into a dataframe that i can later map
#
# Output: The data can be seen as a chart that is now stored in a variable.

# %%
c_count.plot.bar(x='index', y='LICENSED_CERTIFIED', title="Number of Certified and Licensed Healthcare Facilities", color= "yellow")

# %% [markdown]
# Purpose: plot the dataframe into a line graph.
#
# Outcome: I can see a plot of the number of clinics that belong to each category

# %%
clinic.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 12328 entries, 0 to 12327
# Data columns (total 61 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   LICENSED_CERTIFIED              12328 non-null  object
#  1   FLAG                            12328 non-null  object
#  2   T18_19                          12328 non-null  object
#  3   FACID                           12328 non-null  object
#  4   FAC_STATUS_TYPE_CODE            12328 non-null  object
#  5   ASPEN_FACID                     12328 non-null  object
#  6   CCN                             12328 non-null  object
#  7   TERMINAT_SW                     12328 non-null  object
#  8   PARTICIPATION_DATE              12328 non-null  object
#  9   APPROVAL_DATE                   12328 non-null  object
#  10  NPI                             12328 non-null  object
#  11  CAN_BE_DEEMED_FAC_TYPE          12328 non-null  object
# ...

# %% [markdown]
# Purpose: I can see the information about the original dataset I imported
#
# Output: I know how many cells in each of the columns have no values

# %%
qry= ['LICENSED_CERTIFIED', 'LATITUDE', 'LONGITUDE', 'LOCATION', 'geometry']
clinic[qry]
# Out:
#            LICENSED_CERTIFIED     LATITUDE     LONGITUDE  \
# 0      LICENSED AND CERTIFIED    38.256552   -122.628024
# 1      LICENSED AND CERTIFIED    38.438712  -122.7059775
# 2      LICENSED AND CERTIFIED    41.768559   -124.200918
# 3      LICENSED AND CERTIFIED     38.22156   -122.646834
# 4      LICENSED AND CERTIFIED    40.781097    -124.13547
# ...                       ...          ...           ...
# 12323  LICENSED AND CERTIFIED    33.953184   -117.390906
# 12324  LICENSED AND CERTIFIED    34.244721  -118.4500305
# 12325  LICENSED AND CERTIFIED    34.205022  -118.3467915
# 12326  LICENSED AND CERTIFIED  34.17947711  -118.4058586
# 12327  LICENSED AND CERTIFIED    34.063731  -118.2959595
#
#                           LOCATION geometry
# 0          (-122.628024,38.256552)     None
# 1         (-122.7059775,38.438712)     None
# 2          (-124.200918,41.768559)     None
# 3           (-122.646834,38.22156)     None
# 4           (-124.13547,40.781097)     None
# ...

# %% [markdown]
# Purpose: I can select and filter the columns I want to include in my data analyses
#
# Outcome: Only the columns I selected are now added into a new variable for later use.

# %%
c_qry = clinic[qry].copy()
c_qry
# Out:
#            LICENSED_CERTIFIED     LATITUDE     LONGITUDE  \
# 0      LICENSED AND CERTIFIED    38.256552   -122.628024
# 1      LICENSED AND CERTIFIED    38.438712  -122.7059775
# 2      LICENSED AND CERTIFIED    41.768559   -124.200918
# 3      LICENSED AND CERTIFIED     38.22156   -122.646834
# 4      LICENSED AND CERTIFIED    40.781097    -124.13547
# ...                       ...          ...           ...
# 12323  LICENSED AND CERTIFIED    33.953184   -117.390906
# 12324  LICENSED AND CERTIFIED    34.244721  -118.4500305
# 12325  LICENSED AND CERTIFIED    34.205022  -118.3467915
# 12326  LICENSED AND CERTIFIED  34.17947711  -118.4058586
# 12327  LICENSED AND CERTIFIED    34.063731  -118.2959595
#
#                           LOCATION geometry
# 0          (-122.628024,38.256552)     None
# 1         (-122.7059775,38.438712)     None
# 2          (-124.200918,41.768559)     None
# 3           (-122.646834,38.22156)     None
# 4           (-124.13547,40.781097)     None
# ...

# %% [markdown]
# Purpose: Make a copy of the data to prevent the original dataset to become modified.
#
# Outcome: I now have a copy of the data with only the columns I want to use included.

# %%
c_qry.query("LICENSED_CERTIFIED == 'LICENSED ONLY'")
# Out:
#       LICENSED_CERTIFIED     LATITUDE     LONGITUDE  \
# 49         LICENSED ONLY    38.318877   -122.297976
# 52         LICENSED ONLY  38.46464973  -122.6620887
# 62         LICENSED ONLY    38.478708   -122.667327
# 70         LICENSED ONLY    39.425382   -123.806529
# 77         LICENSED ONLY    37.900845   -122.481072
# ...                  ...          ...           ...
# 12277      LICENSED ONLY     33.85872  -118.2987495
# 12300      LICENSED ONLY    34.160184    -118.29843
# 12307      LICENSED ONLY    34.088436   -118.150524
# 12314      LICENSED ONLY    34.078905   -118.697526
# 12322      LICENSED ONLY    33.934743   -118.022112
#
#                           LOCATION geometry
# 49         (-122.297976,38.318877)     None
# 52     (-122.6620887,38.464649732)     None
# 62         (-122.667327,38.478708)     None
# 70         (-123.806529,39.425382)     None
# 77         (-122.481072,37.900845)     None
# ...                            ...      ...
# ...

# %% [markdown]
# Purpose: I only want to select for the clinics that have licensed only under the licensed_certified column of my data.
#
# Output: The only data shown is what includes licensed only.
